# %% [markdown]
# <a href="https://colab.research.google.com/github/sendyprstyo/Sendy_KC_TI1B/blob/main/Sendy_Job5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JOBSHEET 5 PENGAMBILAN DAN PEMBERSIHAN DATA MENGGUNAKAN PANDAS

# %% [markdown]
# ## Latihan

# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('./Data.csv')
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6700000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0         NaN        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung     NaN   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    27.0   6700000.0        Ya

# %% [markdown]
# ### tidak memiliki data kosong (NaN)

# %%
df.isnull().sum()
# Out:
# Negara       0
# Umur         1
# Gaji         1
# Transaksi    0
# dtype: int64

# %% [markdown]
# ### Mengatasi Missing Velues dengan drop data

# %% [markdown]
# #### 1 Hapus data yang kosong (NaN)

# %%
df = pd.read_csv('./Data.csv')
df.dropna(inplace=True)

df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6700000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 5   Jakarta    35.0  10000000.0        Ya
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    27.0   6700000.0        Ya

# %% [markdown]
# ### Mengganti Missing Values dengan Nilai Baru

# %% [markdown]
# #### 2. Ganti Data yang kosong (NaN) menjadi:

# %%
df = pd.read_csv('./Data.csv')
df['Umur'].fillna(50, inplace=True)
df['Gaji'].fillna(25000000, inplace=True)
df
# Out:
# <ipython-input-20-2b0a6985157e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(50, inplace=True)
# <ipython-input-20-2b0a6985157e>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### Mengganti Missing Values dengan nilai mean

# %% [markdown]
# #### Ganti data kosong (NaN) pada umur dan Gaji dengan nilai Rata- rata

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].mean();
mean_gaji = df['Gaji'].mean();

df['Umur'].fillna(mean_umur, inplace=True)
df['Gaji'].fillna(mean_gaji, inplace=True)
df
# Out:
# <ipython-input-22-6b88f0aebe06>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(mean_umur, inplace=True)
# <ipython-input-22-6b88f0aebe06>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### Mengganti Missing Values dengan nilai Median

# %% [markdown]
# #### Ganti data kosong (NaN) pada umur dan gaji dengan nilai median

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].median();
mean_gaji = df['Gaji'].median();

df['Umur'].fillna(mean_umur, inplace=True)
df['Gaji'].fillna(mean_gaji, inplace=True)

df
# Out:
# <ipython-input-23-3f09d7a429bc>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(mean_umur, inplace=True)
# <ipython-input-23-3f09d7a429bc>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### Mengganti Missing values dengan nilai mode

# %% [markdown]
# #### Ganti data kosong (NaN) pada umur dan gaji dengan nilai modus

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].mode()[0];
mean_gaji = df['Gaji'].mode()[0];

df['Umur'].fillna(mean_umur, inplace=True)
df['Gaji'].fillna(mean_gaji, inplace=True)

df
# Out:
# <ipython-input-24-2c203f330538>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur'].fillna(mean_umur, inplace=True)
# <ipython-input-24-2c203f330538>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### Mengubah wrong data dengan ubah data

# %% [markdown]
# #### Apabila ada umur  yang diatas 120 maka ubah menjadi 33

# %%
df = pd.read_csv('./Data.csv')

for x in df.index:
    if df.loc[x, 'Umur'] > 120:
        df.loc[x, 'Umur'] = 33

df
# Out:
#      Negara  Umur        Gaji Transaksi
# 0   Jakarta  44.0   8000000.0     Tidak
# 1   Bandung  27.0   6700000.0        Ya
# 2  Surabaya  30.0   4500000.0     Tidak
# 3   Bandung  38.0   7500000.0     Tidak
# 4  Surabaya  40.0         NaN        Ya
# 5   Jakarta  35.0  10000000.0        Ya
# 6   Bandung   NaN   8250000.0     Tidak
# 7   Jakarta  48.0   9750000.0        Ya
# 8  Surabaya  33.0   7674000.0     Tidak
# 9   Jakarta  27.0   6700000.0        Ya

# %% [markdown]
# TUGAS PRAKTIKUM

# %%
df.groupby('Gas_Station')['Total_Transaksi'].sum().sort_values(ascending=False).head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-6b036f2fefb5> in <cell line: 0>()
# ----> 1 df.groupby('Gas_Station')['Total_Transaksi'].sum().sort_values(ascending=False).head(5)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
# ...
